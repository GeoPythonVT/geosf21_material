# %% [markdown]
# # GitHub Setup - on the ARC web-app

# %% [markdown]
# This instructions are for setting up your GitHub connection with the ARC web-app at:
# https://ood.arc.vt.edu/pun/sys/dashboard/batch_connect/sys/CLASS_geos6104Fall21/session_contexts/new.
# This needs to be done at the beginning of the class.
# Basically, we need to:
# - Configure GitHub
# - Invite me as collaborator to your repository (so your homework can be graded).
# - Configure Git on web-app to allow pushing to your personal repository (this is how you submit homework)
#
# ## Step 1: Sign up for a Github account
#
# https://github.com
#
# ## Step 2: Configure your ssh keys
#
# 1. If you have a key, skip to step 5.
# 2. Open a terminal on your computer, or in Jupyter Lab (click on + to the left and then on Terminal).
# 3. In the terminal window, type:
#     ```shell
#     ssh-keygen
#     ```
# 4. Ideally you will use a short passphrase different from your pid password, but can simply hit enter for most (or all prompts).
# 5. Into the terminal, type:
#     ```shell
#     cat ~/.ssh/id_rsa.pub
#     ```
#    ... and copy the entire output.
# 6. Now, you need to add this to your GitHub profile. In Github, click on the pulldown (top right) to view your profile and choose settings then SSH and GPG keys.
# 7. Click on New SSH key, paste your RSA public key there and save.
#
# ## Step 4: Configure your local Git
#
# To do this, type the following in your Terminal, or the Jupyter QTConsole:
#
#     git config --global user.email <you@example.com>
#     git config --global user.name <GitHubUserName>
#
# ## Step 5: Create a new, empty GitHub repository for your own coursework
#
# On GitHub, create a new, empty repository named:
#
#     geosf21_<pid>
#
# (pid should be your VT PID). For that, click on the 'New' button. Don’t add a *readme* at this time. Make your repository private.
#
# ## Step 6: Add me as a collaborator to your repository
#
# On GitHub, add me as a collaborator under 'Settings' > 'Manage access' of your repository. Please use my GitHub account name 'GeoPythonVT' or my e-mail address 'swerth@vt.edu'.
#
# ## Step 7: Clone the new repository to your local computer
#
# In the terminal window, change directories to where you want your coursework to live, for instance cd ~/Documents/. Then pull your repository onto your computer:
#
#     git clone git@github.com:<GitHubUserName>/geosf21_<pid>.git
#
# Enter into your repository, which is currently empty:
#
#     cd geosf21_<pid>
#
# ## Step 8: Push your first work to your repository
#
# In the terminal, enter the following commands to create new content for your repository and send it to GitHub:
#
#
#     echo "# Geos Python Fall 2021" >> README.md
#     git add README.md
#     git commit -m "first commit"
#     git branch -M main
#     git remote add origin git@github.com:<GitHubUserName>/geosf21_<pid>.git
#     git push -u origin main
#
# If this set of commands is successful you are all setup and have made your first commit. If you refresh the Github page, you should see your README.
#
# **Note: You will need to repeat only some of these commands, when you submit your homework. These are listed on the main page of this repository (in the file readme.md). **
#
# If you want to read more about this:
#
# https://services.github.com/on-demand/downloads/github-git-cheat-sheet/
#
#
# # Copy / Clone the course repository to your own computer
#
# In the terminal window, go at least one directory up:
#
#     cd ..
#
# Or go into another directory where you want the course material to live. The following command copies the course material repository to your computer to the folder './geosf21_material'.
#
#     git clone git@github.com:GeoPythonVT/geosf21_material.git
#
# You will not push any content to this repository. However, you can pull new content from this repository, whenever there is new material available. Alternatively, you can download the material directly from the repositories website:
#
# https://github.com/GeoPythonVT/geosf21_material
